# %%
import matplotlib.pyplot as plt
from datetime import date

# %%
def dayformat(day):
    maanden = ['januari', 'februari', 'maart', 'april', 'mei', 'juni',
               'juli', 'augustus', 'september', 'oktober', 'november', 'december']
    dag = day.split()
    dag[1] = maanden.index(dag[1]) + 1
    return date(int(dag[2]), dag[1], int(dag[0]))

# %%
#86 Axelle Geelen
#151 Lien
#16 SAC

file = open('C:/Users/votsius/Downloads/facebook-lucasotodegraeve/messages/89.html', 'r', encoding='utf-8')
# file = 'text-align: center;</style><title>Gesprek met Axelle Geelen</title></head><body><a href="html/messages.htm">Back</a><br /><br /><div class="thread">Gesprek met&nbsp;Axelle Geelen<div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 17 november 2017 om 23:22 UTC+01</span></div></div><p>I’ll try ;)</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 17 november 2017 om 22:47 UTC+01</span></div></div><p>Stay strong</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 17 november 2017 om 22:47 UTC+01</span></div></div><p>En Hmm not sure! Mss op de moment zelf</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 17 november 2017 om 22:47 UTC+01</span></div></div><p>Zot he, trots?</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 17 november 2017 om 22:23 UTC+01</span></div></div><p>Dus wss ni veel vrije tijd for this boi?</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 17 november 2017 om 22:21 UTC+01</span></div></div><p>Wow wow zo verantwoordelijk</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 17 november 2017 om 22:03 UTC+01</span></div></div><p>Leren en morgen eten bij vriendjes en zondag mams verjaardaggg</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 17 november 2017 om 22:03 UTC+01</span></div></div><p>Hey boy</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 17 november 2017 om 21:44 UTC+01</span></div></div><p>What u doin dis weekend 😗</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 17 november 2017 om 21:44 UTC+01</span></div></div><p>Hey girl</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">woensdag 15 november 2017 om 17:31 UTC+01</span></div></div><p>Nopes</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">woensdag 15 november 2017 om 17:29 UTC+01</span></div></div><p>Gij ni eh</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">woensdag 15 november 2017 om 17:29 UTC+01</span></div></div><p>Heeft laure kinepolis studentenkaart?</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">woensdag 15 november 2017 om 17:07 UTC+01</span></div></div><p>Is goed!</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">woensdag 15 november 2017 om 16:53 UTC+01</span></div></div><p>Ook vr u en laure?</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">woensdag 15 november 2017 om 16:53 UTC+01</span></div></div><p>Kga sebiet tickets kopen vr de groep</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:23 UTC+01</span></div></div><p>Jawel</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:23 UTC+01</span></div></div><p>Aaaa</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:17 UTC+01</span></div></div><p>Ik snap het niet help</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:17 UTC+01</span></div></div><p>Ik?</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 20:16 UTC+01</span></div></div><p>*dabs*</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 20:16 UTC+01</span></div></div><p>Jeh just wait a little longer</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:16 UTC+01</span></div></div><p>Meat</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 20:15 UTC+01</span></div></div><p>O we meat on te way</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 20:15 UTC+01</span></div></div><p>Okkkz ik kom afff</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:15 UTC+01</span></div></div><p>Ben nog in Ufo wel</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 20:15 UTC+01</span></div></div><p>Ik ben klaar</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 20:09 UTC+01</span></div></div><p>Stuur mij wnr kmoe afkomen :p</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 18:28 UTC+01</span></div></div><p>Examen is tot kwart voor 8 hihi</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">dinsdag 14 november 2017 om 18:28 UTC+01</span></div></div><p>Hahhaha loser</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 18:02 UTC+01</span></div></div><p>Of kunt uw babe komen halen xxx</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">dinsdag 14 november 2017 om 18:01 UTC+01</span></div></div><p>Stuurt ge mij wnr da je klaar zijt?</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 18:04 UTC+01</span></div></div><p>🖕🏼</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 18:00 UTC+01</span></div></div><p>😘</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 18:00 UTC+01</span></div></div><p>Sukkel</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 18:00 UTC+01</span></div></div><p>En ward</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 18:00 UTC+01</span></div></div><p>&lt;3</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 18:00 UTC+01</span></div></div><p>Ja daarom kom ik ni</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Ik en Q zijn hier</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Boeh</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Hmmm khad gzgd tegen sjoerd dak op hem ging wachten :p</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Die van 40</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Ie eeft vertraging</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Loop</p><div class="message"><div class="message_header"><span class="user">Axelle Geelen</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Kom snel 2</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Ga je er geraken?</p><div class="message"><div class="message_header"><span class="user">Luca Soto De Graeve</span><span class="meta">vrijdag 10 november 2017 om 17:59 UTC+01</span></div></div><p>Ben al aan station</p></div></body></html>'

conv = file.read().split('<span class="user">')
# conv = file.split('<span class="user">')

aantallen = []
dagen = []
data = [] # dag voor elk bericht
users = [] # korte lijst met deelnemers
senders = [] # lange lijst stuurder van elk bericht
word_count = [] # hoeveel woorden per user
message_count = [] # hoeveel berichten per user
word_count_ogenblikkelijk = [] # woorden per user per bericht
word_count_per_dag = [] # woorden per user per dag

del conv[0]
for i in range(len(conv)):
    
#     if i%50000==0:
#         print('{}/{}'.format(i, len(conv)))
    
    temp = conv[i].split('</span><span class="meta">') #splits in sender en rest
    message = temp[1].split('</p><div')[0].split('</span></div></div><p>') #datum en bericht
    
    senders.append(temp[0]) #sender
    datum = message[0].split('om')[0].strip().split('dag')[1].strip() #tijd
    data.append(datum)
    conv[i] = message[1] #bericht
    
    if senders[i] not in users:
        users.append(senders[i])
        word_count.append(0)
        message_count.append(0)
        
    if senders[i] in users:
        aantal_woorden = len(conv[i].split())
        word_count[users.index(senders[i])] += aantal_woorden
        message_count[users.index(senders[i])] += 1
        
    if datum not in dagen:
        dagen.append(datum)
        aantallen.append(0)
        
    if datum in dagen:
        aantallen[-1] += 1
        
for user in users:
    word_count_ogenblikkelijk.append([0])
    word_count_per_dag.append([0])
        
print('Step 1 done')
        
for i in range(1, len(conv)+1):
    for u in range(len(users)):
        word_count_ogenblikkelijk[u].append(word_count_ogenblikkelijk[u][-1])
    word_count_ogenblikkelijk[users.index(senders[-i])][-1] += len(conv[-i].split())

#     if i%5000==0:
#         print('{}/{}'.format(i, len(conv)))
    
    if data[-i] not in data[-i+1:]:
        for u in range(len(users)):
            word_count_per_dag[u].append(word_count_per_dag[u][-1])
        word_count_per_dag[users.index(senders[-i])][-1] += len(conv[-i].split())
        
        
    if data[-i] in data[-i+1:]:
        word_count_per_dag[users.index(senders[-i])][-1] += len(conv[-i].split())
        
print(users)
print(message_count)
print(word_count)
# Out:
# Step 1 done
# ['Luca Soto De Graeve', 'Axelle Geelen']
# [11761, 10740]
# [66263, 52850]

# %%
d0 = dayformat(dagen[-1])
x_as = []
y_as = []

for i in range(1, len(dagen)+1):
    y_as.append(aantallen[-i])
    x_as.append((dayformat(dagen[-i])-d0).days)

# %%
#fig, (ax1, ax2) = plt.subplots(2, figsize=(17, 10))
fig, (ax1, ax2) = plt.subplots(2, figsize=(50, 30))


ax1.plot(x_as, y_as, 'o')
ax1.set_ylabel('Aantal berichten')
ax1.set_xlabel('Tijd (per dag)')

# xlen = len(word_count_ogenblikkelijk[0])
for u in range(len(users)):
    ax2.plot(x_as, word_count_per_dag[u])

ax2.set_ylabel('Aantal woorden')
ax2.set_xlabel('Tijd (per dag)')
ax2.legend(users)

ax1.set_title('Facebook analyse (Axelle, 24/02/18)')
plt.show()

#fig.savefig('Axelle_v7.png')

# %%
print(y_as[-1])
print(data[0])
# Out:
# 671
# 23 december 2017
